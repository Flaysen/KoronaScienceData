# %%
def rectangle_area(a, b):
  if a<0 or b<0:
    raise ValueError("if either number was negative")
  return a*b

# %%
import pandas as pd
from datetime import datetime
import numpy as np


wczoraj = datetime.today().day-1
miesiac = datetime.today().month


def check(dzien, mies):
	url = f"https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv"
	df = pd.read_csv(url, error_bad_lines=False)
	result = df.loc[df["Country/Region"]=="Poland"][f"{mies}/{dzien}/20"].values[0]
	print(result)
	return result
 

print(f"data: {wczoraj}/{miesiac}")
print("przypadki: ", check(wczoraj, miesiac))
# Out:
# data: 16/3
# 177
# przypadki:  177

# %%
check(wczoraj,miesiac)
# Out:
# 177
# 177

# %%
df = pd.DataFrame({
    'col1': ['A', 'A', 'B', np.nan, 'D', 'C'],
    'col2': [2, 1, 9, 8, np.nan, 4],
    'col3': [0, 1, 9, 4, 2, 3],
})
df
# Out:
#   col1  col2  col3
# 0    A   2.0     0
# 1    A   1.0     1
# 2    B   9.0     9
# 3  NaN   8.0     4
# 4    D   NaN     2
# 5    C   4.0     3

# %%
df.sort_values(by=["col1"])
# Out:
#   col1  col2  col3
# 0    A   2.0     0
# 1    A   1.0     1
# 2    B   9.0     9
# 5    C   4.0     3
# 4    D   NaN     2
# 3  NaN   8.0     4

# %%
df.sort_values(by=["col1","col2"])
# Out:
#   col1  col2  col3
# 1    A   1.0     1
# 0    A   2.0     0
# 2    B   9.0     9
# 5    C   4.0     3
# 4    D   NaN     2
# 3  NaN   8.0     4

# %%
df.sort_values(by=["col1","col2"], ascending=False)
# Out:
#   col1  col2  col3
# 4    D   NaN     2
# 5    C   4.0     3
# 2    B   9.0     9
# 0    A   2.0     0
# 1    A   1.0     1
# 3  NaN   8.0     4

# %%
df.sort_values(by=["col1","col2"], ascending=False, na_position="first")
# Out:
#   col1  col2  col3
# 3  NaN   8.0     4
# 4    D   NaN     2
# 5    C   4.0     3
# 2    B   9.0     9
# 0    A   2.0     0
# 1    A   1.0     1

# %%
df["col2"].fillna(df["col2"].mean(), inplace=True)

# %%
df.loc[df.col1=="A"]
# Out:
#   col1  col2  col3
# 0    A   2.0     0
# 1    A   1.0     1

# %%
df.loc[(df.index>1)&(df.index<4)]
# Out:
#   col1  col2  col3
# 2    B   9.0     9
# 3  NaN   8.0     4

# %%
df.iloc[2:4,:]
# Out:
#   col1  col2  col3
# 2    B   9.0     9
# 3  NaN   8.0     4

# %%
df
# Out:
#   col1  col2  col3
# 0    A   2.0     0
# 1    A   1.0     1
# 2    B   9.0     9
# 3  NaN   8.0     4
# 4    D   4.8     2
# 5    C   4.0     3

# %%
df.groupby("col1").sum()
# Out:
#       col2  col3
# col1
# A      3.0     1
# B      9.0     9
# C      4.0     3
# D      4.8     2

# %%
df.rename(columns={"col1":"kolumna1"})
# Out:
#   kolumna1  col2  col3
# 0        A   2.0     0
# 1        A   1.0     1
# 2        B   9.0     9
# 3      NaN   8.0     4
# 4        D   4.8     2
# 5        C   4.0     3

# %%
url = f"https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv"
df = pd.read_csv(url, error_bad_lines=False)

# %%
df
# Out:
#      Province/State  Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0               NaN        Thailand  15.0000  101.0000        2        3
# 1               NaN           Japan  36.0000  138.0000        2        1
# 2               NaN       Singapore   1.2833  103.8333        0        1
# 3               NaN           Nepal  28.1667   84.2500        0        0
# 4               NaN        Malaysia   2.5000  112.5000        0        0
# ..              ...             ...      ...       ...      ...      ...
# 458             NaN         Somalia   5.1521   46.1996        0        0
# 459             NaN        Tanzania  -6.3690   34.8888        0        0
# 460             NaN     The Bahamas  24.2500  -76.0000        0        0
# 461  Virgin Islands              US  18.3358  -64.8963        0        0
# 462  Cayman Islands  United Kingdom  19.3133  -81.2546        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/7/20  3/8/20  3/9/20  3/10/20  \
# 0          5        7        8        8  ...      50      50      50       53
# 1          2        2        4        4  ...     461     502     511      581
# 2          3        3        4        5  ...     138     150     150      160
# 3          0        1        1        1  ...       1       1       1        1
# 4          0        3        4        4  ...      93      99     117      129
# ..       ...      ...      ...      ...  ...     ...     ...     ...      ...
# 458        0        0        0        0  ...       0       0       0        0
# 459        0        0        0        0  ...       0       0       0        0
# 460        0        0        0        0  ...       0       0       0        0
# 461        0        0        0        0  ...       0       0       0        0
# 462        0        0        0        0  ...       0       0       0        0
#
#      3/11/20  3/12/20  3/13/20  3/14/20  3/15/20  3/16/20
# 0         59       70       75       82      114      147
# 1        639      639      701      773      839      825
# 2        178      178      200      212      226      243
# 3          1        1        1        1        1        1
# 4        149      149      197      238      428      566
# ..       ...      ...      ...      ...      ...      ...
# 458        0        0        0        0        0        1
# 459        0        0        0        0        0        1
# 460        0        0        0        0        0        1
# 461        0        0        0        1        1        1
# 462        0        0        1        1        1        1
#
# [463 rows x 59 columns]

# %%
#liczba przypadków - miejsca z największą liczbą przypadków
def top(data):
  return df[["Province/State", "Country/Region", data]].sort_values(by=data).tail(10)

# %%
data14="3/15/20"

# %%
top(data14)
# Out:
#     Province/State Country/Region  3/15/20
# 159          Henan          China     1273
# 158      Guangdong          China     1360
# 31             NaN    Switzerland     2200
# 157         France         France     4499
# 11             NaN        Germany     5795
# 18             NaN          Spain     7798
# 156            NaN   Korea, South     8162
# 155            NaN           Iran    13938
# 16             NaN          Italy    24747
# 154          Hubei          China    67794

# %%
#kolorowe kredki dla DataFrame
df.loc[df["Country/Region"]=="China",:].sort_values(by=data14).tail(10).head(9).style.background_gradient(cmap='magma')
# Out:
# <style  type="text/css" >
#     #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col2 {
#             background-color:  #bd3977;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col3 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col4 {
#             background-color:  #3b0f70;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col5 {
#             background-color:  #241253;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col6 {
#             background-color:  #902a81;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col7 {
#             background-color:  #ed5a5f;
#             color:  #000000;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col8 {
#             background-color:  #c53c74;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col9 {
#             background-color:  #e04c67;
#             color:  #000000;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col10 {
#             background-color:  #a1307e;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col11 {
#             background-color:  #4e117b;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col12 {
#             background-color:  #311165;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col13 {
#             background-color:  #19103f;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col14 {
#             background-color:  #19103f;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col15 {
#             background-color:  #2a115c;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col16 {
#             background-color:  #2c115f;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col17 {
#             background-color:  #2c115f;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col18 {
#             background-color:  #21114e;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col19 {
#             background-color:  #150e38;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col20 {
#             background-color:  #090720;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col21 {
#             background-color:  #020109;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col22 {
#             background-color:  #030312;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col23 {
#             background-color:  #03030f;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col24 {
#             background-color:  #02020d;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col25 {
#             background-color:  #03030f;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col26 {
#             background-color:  #02020d;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col27 {
#             background-color:  #020109;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col28 {
#             background-color:  #020109;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col29 {
#             background-color:  #020109;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col30 {
#             background-color:  #010108;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col31 {
#             background-color:  #010108;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col32 {
#             background-color:  #02020b;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col33 {
#             background-color:  #02020d;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col34 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col35 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col36 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col37 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col38 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col39 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col40 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col41 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col42 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col43 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col44 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col45 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col46 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col47 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col48 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col49 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col50 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col51 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col52 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col53 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col54 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col55 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col56 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col57 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row0_col58 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row1_col2 {
#             background-color:  #fb835f;
#             color:  #000000;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row1_col3 {
#             background-color:  #fde5a7;
#             color:  #000000;
#         }    #T_867eb2ae_6838_11ea_bd48_48f17f403ab6row1_col4 {
#             background-

# %%
#brak przypadkow do danego dnia (włacznie)
def brakwirusa(data):
  return df.loc[df[data]==0].index

# %%
brakwirusa(data14)
# Out:
# Int64Index([ 22, 152, 210, 211, 212, 213, 214, 215, 216, 217,
#             ...
#             450, 451, 452, 453, 454, 455, 457, 458, 459, 460],
#            dtype='int64', length=207)

# %%
import plotly.express as px

# %%
formated_gdf = df.groupby(["Country/Region"]).max()

# %%
formated_gdf =  formated_gdf.reset_index()

# %%
formated_gdf['size'] = formated_gdf[data14].pow(0.3)

# %%
formated_gdf['size'] = formated_gdf[data14].pow(0.3)

# %%
formated_gdf
# Out:
#                      Country/Region Province/State      Lat      Long  \
# 0                       Afghanistan            NaN  33.0000   65.0000
# 1                           Albania            NaN  41.1533   20.1683
# 2                           Algeria            NaN  28.0339    1.6596
# 3                           Andorra            NaN  42.5063    1.5218
# 4               Antigua and Barbuda            NaN  17.0608  -61.7964
# ..                              ...            ...      ...       ...
# 151                         Uruguay            NaN -32.5228  -55.7658
# 152                      Uzbekistan            NaN  41.3775   64.5853
# 153                       Venezuela            NaN   6.4238  -66.5897
# 154                         Vietnam            NaN  16.0000  108.0000
# 155  occupied Palestinian territory            NaN  31.9522   35.2332
#
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/8/20  \
# 0          0        0        0        0        0        0  ...       4
# 1          0        0        0        0        0        0  ...       0
# 2          0        0        0        0        0        0  ...      19
# 3          0        0        0        0        0        0  ...       1
# 4          0        0        0        0        0        0  ...       0
# ..       ...      ...      ...      ...      ...      ...  ...     ...
# 151        0        0        0        0        0        0  ...       0
# 152        0        0        0        0        0        0  ...       0
# 153        0        0        0        0        0        0  ...       0
# 154        0        2        2        2        2        2  ...      30
# 155        0        0        0        0        0        0  ...       0
#
#      3/9/20  3/10/20  3/11/20  3/12/20  3/13/20  3/14/20  3/15/20  3/16/20  \
# 0         4        5        7        7        7       11       16       21
# 1         2       10       12       23       33       38       42       51
# 2        20       20       20       24       26       37       48       54
# 3         1        1        1        1        1        1        1        2
# 4         0        0        0        0        1        1        1        1
# ..      ...      ...      ...      ...      ...      ...      ...      ...
# 151       0        0        0        0        0        4        4        8
# 152       0        0        0        0        0        0        1        6
# 153       0        0        0        0        0        2       10       17
# 154      30       31       38       39       47       53       56       61
# 155       0        0        0        0        0        0        0        0
#
#          size
# 0    2.297397
# 1    3.068844
# 2    3.194276
# 3    1.000000
# 4    1.000000
# ..        ...
# 151  1.515717
# 152  1.000000
# 153  1.995262
# 154  3.345464
# 155  0.000000
#
# [156 rows x 60 columns]

# %%
formated_gdf = df.groupby

# %%
fig = px.scatter_geo(formated_gdf, locations="Country/Region", locationmode='country names', 
                     color="3/14/20", size="size", hover_name="Country/Region", 
                     range_color= [0, max(formated_gdf['3/14/20'])+2], 
                     projection="natural earth", 
                     title="COVID-19 na swiecie" 
                     )
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-26c7f8a17f8a> in <module>
#       1 fig = px.scatter_geo(formated_gdf, locations="Country/Region", locationmode='country names',
#       2                      color="3/14/20", size="size", hover_name="Country/Region",
# ----> 3                      range_color= [0, max(formated_gdf['3/14/20'])+2],
#       4                      projection="natural earth",
#       5                      title="COVID-19 na swiecie"
#
# TypeError: 'method' object is not subscriptable
